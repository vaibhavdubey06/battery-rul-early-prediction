# %% [markdown]
# # 02 - Feature Engineering
#
# This notebook focuses on extracting and engineering features for RUL prediction.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

import sys
sys.path.append('../src')
from feature_extraction import extract_features

# %% [markdown]
# ## Load Processed Data

# %%
# TODO: Load data and extract features

# %% [markdown]
# ## Feature Extraction

# %%
# TODO: Add feature engineering code

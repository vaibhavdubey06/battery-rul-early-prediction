# %% [markdown]
# # 01 - Data Exploration
#
# This notebook explores the battery dataset to understand its structure and characteristics.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
# TODO: Load your battery dataset here
# data = pd.read_csv('../data/battery_data.csv')

# %% [markdown]
# ## Data Overview

# %%
# TODO: Add data exploration code

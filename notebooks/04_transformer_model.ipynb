# %% [markdown]
# # 04 - Transformer Model for RUL Prediction
#
# This notebook implements a Transformer-based model for battery RUL prediction.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

import sys
sys.path.append('../src')
from models import TransformerModel
from train import train_model, evaluate_model

# %% [markdown]
# ## Prepare Data

# %%
# TODO: Load and prepare data for Transformer

# %% [markdown]
# ## Build and Train Transformer Model

# %%
# TODO: Build and train Transformer model

# %% [markdown]
# ## Evaluate Model

# %%
# TODO: Evaluate and visualize results

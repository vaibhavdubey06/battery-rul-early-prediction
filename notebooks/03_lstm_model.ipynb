# %% [markdown]
# # 03 - LSTM Model for RUL Prediction
#
# This notebook implements an LSTM-based model for battery RUL prediction.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

import sys
sys.path.append('../src')
from models import LSTMModel
from train import train_model, evaluate_model

# %% [markdown]
# ## Prepare Data

# %%
# TODO: Load and prepare data for LSTM

# %% [markdown]
# ## Build and Train LSTM Model

# %%
# TODO: Build and train LSTM model

# %% [markdown]
# ## Evaluate Model

# %%
# TODO: Evaluate and visualize results
